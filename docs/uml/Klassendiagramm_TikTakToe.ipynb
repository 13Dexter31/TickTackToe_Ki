# %%
import iplantuml

# %%
# %%plantuml
#
# class Game {
# -player[] players
# -__init__(players)
# +run()
# -turn(player, board)
# }
#
# class Board {
# +POSSIBLE_ACTIONS
# +SHAPE
# -field
# -__init__()
# -__str__()
# -__getitem__(index)
# +update(action, player)
# +get_equivalent_fields()
# +get_field_copy()
# +get_default_dict()
# -__markPlayer(column, row, player)
# -__over()
# -__no_more_moves()
# }
#
# class Player {
# -__init__(representationChar)
# -__str__()
# +makeMove(board)
# +giveResult(result)
# }
#
# class Stats {
# +display()
# +display_history()
# }
#
# class Randy {
# }
#
# class Human {
# }
#
# class QPlayer {
# }
#
# enum Result{
#     NO_RESULT = 0
# GAME_WON = 1
# GAME_LOST = 2
# GAME_DRAW = 3
# INVALID_MOVE = 4
# }
#
# Game -- Player
# Game -- Board
# Game -- Result
#
# Player <|-- KI
# Player <|-- Human
# Player <|-- QPlayer
# Player -- Result
#
# Stats -- Player
#
# Board -- Result
