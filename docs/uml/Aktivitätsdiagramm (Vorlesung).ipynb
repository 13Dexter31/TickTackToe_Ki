# %%
import plantuml

# %%
# %%plantuml
#
# |Programm|
# start
# repeat
# :startet;
# |Spieler 1|
# :zug;
# |Programm|
# if (vorbei?) then (yes)
# :resultat anzeigen;
#     break
#     endif
# repeat while (Eingabe?)
# Out:
# UsageError: Cell magic `%%plantuml` not found.

# %% [markdown]
# ![Aktivitätsdiagramm.drawio.png](attachment:Aktivitätsdiagramm.drawio.png)

# %%
# %%plantuml
# |Spieler|
# start
# repeat
# :zug ermitteln;
# :zug ausführen;
# |Programm|
# if (korrekt?) then (yes)
#     :update spielfeld;
#     stop
# else (no)
#     :return error;
