# %%
import plantuml

# %%
# %%plantuml
#
# class Game {
#     -Spielfeld spielfeld
#     -Spieler Spieler1
#     -Spieler Spieler2
#     +init()
#     +Spiel(Spieler Spieler1, Spieler Spieler2)
#     +result isOver()
#     +void giveFeedback(Result result)
#
# }
#
# class Board{
#     -int Felder
#     -Regeln regeln
#     +bool update(Position)
#     +visualize()
#     +vorbei()
# }
#
# class Player{
#     +Spieler()
#     +Position makeMove(Spielfeld)
#     +void feedback(Feedback feedback)
# }
# class KI{
#
# }
#
# class Human{
#     -Spielfeld spielfeld
# }
#
# class Position{
#
# }
#
# class Rules{
#
# }
#
# enum Feedback{
#
# }
#
# enum Result{
#     Unentschieden
#     Spieler1Gewinnt
#     Spieler2Gewinnt
#     SpielGehtWeiter
# }
#
# Game -- Player
# Game -- Board
# Game -- Result
#
# Player <|-- KI
# Player <|-- Human
# Player -- Position
# Player -- Feedback
#
# Board -- Position
# Board -- Rules
