# %%
import plantuml

# %%
# %%plantuml
#
# class Spiel {
#     -Spielfeld spielfeld
#     -Spieler Spieler1
#     -Spieler Spieler2
#     +result isOver()
#     +void giveFeedback(Result result)
#
# }
#
# class Spielfeld{
#     -int Felder
# }
#
# class Spieler{
#     +Position makeMove()
#     +void feedback(Feedback feedback)
# }
# class KI{
#
# }
#
# class Human{
#
# }
#
# class Position{
#
# }
#
# enum Feedback{
#
# }
#
# enum Result{
#     Vorbei
#     Spieler1Gewinnt
#     Spieler2Gewinnt
#     SpielGehtWeiter
# }
#
# Spiel -- Spieler
# Spiel -- Spielfeld
# Spiel -- Result
#
# Spieler <|-- KI
# Spieler <|-- Human
# Spieler -- Position
# Spieler -- Feedback
