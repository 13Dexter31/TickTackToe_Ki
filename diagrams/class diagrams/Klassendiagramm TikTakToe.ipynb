# %%
import plantuml

# %%
# %%plantuml
#
# class Game {
#     -Board Board
#     -Player Player1
#     -Player Player2
#     +__init__(self, board, player1, player2)
#     +void giveFeedback(Result result)
#     +Game(self,board,player1,player2)
#
# }
#
# class Board{
#     -int Field
#     -Rules rules
#     -Player player
#     +bool update(self, position, player)
#     +visualize()
#     +over(self)
#     +markPlayer(self, position, player)
#     +__init__(self)
#     +__getitem__(self, index)
#     +noMoreMoves(self)
#     +clear(self)
# }
#
# class Player{
#     +Player()
#     +Position makeMove(Board)
#     +void feedback(Feedback feedback)
# }
# class KI{
#
# }
#
# class Human{
#     -Board board
# }
#
# class Position{
#     +__init__(self, pair)
#     +rowConverted(self)
#     +columnAsInt(self)
#     +isValid(self)
# }
#
# class Rules{
#
# }
#
# enum Feedback{
#
# }
#
# enum Result{
#     No
#     Draw
#     Player1Wins
#     Player2Wins
#     GameGoesOn
#     MoveInvalid
# }
#
# Game -- Player
# Game -- Board
# Game -- Result
#
# Player <|-- KI
# Player <|-- Human
# Player -- Position
# Player -- Feedback
#
# Board -- Position
# Board -- Rules
