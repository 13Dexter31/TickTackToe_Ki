# %%
import plantuml

# %% [markdown]
# ![Aktivitätsdiagramm.drawio.png](attachment:Aktivitätsdiagramm.drawio.png)

# %%
# %%plantuml
# |Spieler 1|
# start
# repeat
# :zug ermitteln;
# :zug ausführen;
# if (korrekt?) then (yes)
#     :update spielfeld;
#     stop
# else (no)
#     :return error;
