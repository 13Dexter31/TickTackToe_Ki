# %% [markdown]
# # Setup

# %%
from build.Game import Game
from build.player.Randy import Randy
from build.player.Human import Human
from build.player.QPlayer import QPlayer, QUtils
from build.player.qlearner.QTableLearner import QTableLearner
from tqdm.notebook import trange

# %%
filepath = '..\\output\\storage\\qtable.pkl'

# %% [markdown]
# # Q-Table Learning

# %%
for j in trange(100):

    player1 = QPlayer('x', QTableLearner(q_table=QUtils.get_dict_from_file(filepath)))
    player2 = QPlayer('o', QTableLearner(q_table=QUtils.get_dict_from_file(filepath)))
    players = [player1, player2]

    game = Game(players)

    for i in range(1000):
        game.run()

    dict = QUtils.merge_dicts(player1.q_learner.q_table, player2.q_learner.q_table)

    QUtils.save_dict_to_file(filepath, dict)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
q_table = QUtils.get_dict_from_file(filepath)
QUtils.pretty_print_q_table(q_table)
# Out:
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [454.89 386.33 446.7 ]
#  [369.07 415.97 342.23]
#  [404.65 397.14 437.25]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#
#  [ 452.68  139.98  201.26]
#  [-644.58 -650.12  158.38]
#  [ 426.03  138.79  199.97]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['x' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [-774.58  210.77  309.52]
#  [-780.85 -775.32   35.16]
#  [-760.05   96.98   78.1 ]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#  [' ' ' ' 'o']
#
#  [ 258.83  311.71  439.5 ]
#  [ 385.14 -610.27  415.66]
#  [ 308.98  494.51 -618.05]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  [' ' 'x' ' ']
#  [' ' ' ' 'o']
#
#  [-729.42   72.71 -773.75]
#  [ 221.1  -718.3   322.66]
#  [ 164.03  212.92 -772.47]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' 'x' ' ']
#  ['x' ' ' 'o']
#
#  [-718.46  -33.3  -912.95]
#  [-795.16 -772.55   -3.39]
#  [-795.4   -38.08 -795.47]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  ['o' 'x' ' ']
#  ['x' 'x' 'o']
#
#  [-1003.81 -1003.73 -1003.72]
#  [-1003.79 -1003.82    -4.86]
#  [-1003.73 -1003.81 -1003.78]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [ 593.88 -586.5   319.24]
#  [ 217.41  288.76  333.66]
#  [ 357.62  333.78 -573.7 ]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [ 282.52 -810.76 -757.99]
#  [-791.31  180.82   73.56]
#  [ 125.83   77.6  -793.04]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#
#  [ 411.05  183.1   173.69]
#  [ 399.51 -643.44  198.22]
#  [-647.61  387.01  338.24]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'o' ' ']
#  ['x' ' ' 'x']
#
#  [ 145.1   192.6   168.7 ]
#  [-633.12 -674.56  252.5 ]
#  [-677.54  460.15 -693.39]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['o' 'o' ' ']
#  ['x' ' ' 'x']
#
#  [-584.55 -605.3   313.  ]
#  [-611.79 -588.38  443.91]
#  [-529.16  589.15 -568.02]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [-538.45  431.85  612.5 ]
#  [ 420.66  257.33  252.55]
#  [ 459.61  260.18 -535.42]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' 'x' ' ']
#  [' ' ' ' 'o']
#
#  [-751.13  254.15  356.99]
#  [-760.34 -762.04  164.39]
#  [ 161.47  364.64 -770.36]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['o' 'x' 'o']
#  [' ' ' ' 'o']
#
#  [-536.23 -558.87  422.25]
#  [-614.33 -664.47 -588.71]
#  [ 213.46  298.1  -603.76]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#
#  [-635.39  402.32  346.41]
#  [ 507.38 -633.48  344.51]
#  [ 355.46  294.25  185.9 ]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#
#  [-768.98 -766.62  179.07]
#  [ 289.69 -768.28  141.66]
#  [ 160.66 -790.95  110.87]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['o' 'x' ' ']
#  ['x' 'o' ' ']
#
#  [-600.9  -671.92  506.93]
#  [-532.41 -556.96  237.77]
#  [-644.18 -584.27  192.96]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['o' 'x' ' ']
#  ['x' 'o' 'x']
#
#  [-1003.38 -1003.11 -1002.3 ]
#  [-1003.47 -1003.28    -4.73]
#  [-1003.05 -1003.5  -1002.65]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' 'o']
#  [' ' ' ' ' ']
#
#  [ 568.81 -590.36  383.04]
#  [ 223.97  339.29 -585.51]
#  [ 181.79  337.8   206.23]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  [' ' ' ' 'o']
#  [' ' 'o' ' ']
#
#  [-516.22 -516.94  714.23]
#  [ 340.14  312.29 -517.16]
#  [ 333.96 -493.55  337.25]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['o' ' ' 'o']
#  [' ' 'o' 'x']
#
#  [-647.73 -603.1   476.97]
#  [-665.53  392.95 -538.13]
#  [ 128.19 -547.68 -579.35]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['o' ' ' 'o']
#  ['x' 'o' 'x']
#
#  [-257.14 -251.07 -246.18]
#  [-250.05  962.1  -246.58]
#  [-251.92 -236.97 -246.27]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' 'o']
#  ['x' ' ' ' ']
#
#  [ 262.91 -724.13   57.63]
#  [ 166.54 -503.84 -750.04]
#  [-762.97   67.87  127.21]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  [' ' 'o' 'o']
#  ['x' ' ' ' ']
#
#  [-507.09 -559.25 -515.86]
#  [ 597.12 -437.04 -524.55]
#  [-504.52  350.33  396.74]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#
#  [ 271.61  358.19  239.21]
#  [ 194.87  427.71  210.34]
#  [-678.8  -681.79  186.66]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#
#  [-727.06  103.29 -828.97]
#  [ 252.53  114.61  232.43]
#  [-713.27 -648.99   55.01]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  [' ' ' ' 'o']
#  ['o' 'x' ' ']
#
#  [-656.75 -431.34 -659.05]
#  [  87.07  247.21 -380.73]
#  [-369.64 -508.44   21.58]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  [' ' 'o' 'o']
#  ['o' 'x' 'x']
#
#  [-991.8  -984.33 -991.84]
#  [  -3.81 -986.19 -994.81]
#  [-944.27 -982.25 -986.16]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [ 539.27  423.15 -536.94]
#  [ 215.37  395.52  171.56]
#  [ 357.96  206.89 -542.12]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['x' ' ' ' ']
#  [' ' 'o' 'o']
#
#  [ 125.57   75.47 -613.3 ]
#  [-554.42  118.9   106.97]
#  [ 247.71 -798.95 -669.01]
#
# -------------------------
#
#  ['x' ' ' 'x']
#  ['x' 'o' ' ']
#  [' ' 'o' 'o']
#
#  [-550.5   401.97 -609.98]
#  [-654.14 -474.71  185.89]
#  [ 437.23 -621.09 -626.06]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  ['o' ' ' 'x']
#
#  [ 604.51  223.19  306.49]
#  [ 191.74  319.15  340.62]
#  [-516.24  160.08 -533.17]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#  ['o' ' ' 'x']
#
#  [-361.15 -358.37  378.11]
#  [ 191.76  861.91  370.45]
#  [-383.78  233.04 -363.82]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'o' ' ']
#  ['o' 'x' 'x']
#
#  [-667.95 -834.87  286.  ]
#  [  67.88 -634.65  132.28]
#  [-515.4  -766.77 -743.74]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['x' 'o' 'o']
#  ['o' 'x' 'x']
#
#  [-1002.16 -1000.35    -4.59]
#  [-1003.09 -1001.53 -1003.09]
#  [-1003.03 -1002.55 -1002.63]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [ 423.86  181.31  333.97]
#  [ 447.57  300.71 -658.33]
#  [-658.83  348.82  342.93]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' 'x' 'o']
#  ['x' ' ' ' ']
#
#  [-656.12  207.66  476.12]
#  [ 164.99 -579.49 -634.69]
#  [-557.98  169.37  195.48]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' 'x' 'o']
#  ['x' ' ' 'x']
#
#  [-602.09  304.54  454.52]
#  [-591.72 -682.13 -545.76]
#  [-665.17  297.47 -577.82]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#  [' ' ' ' 'x']
#
#  [ 589.18  220.73  200.99]
#  [ 203.83  320.55 -576.94]
#  [ 358.07  341.38 -568.49]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' 'o']
#  [' ' 'o' 'x']
#
#  [ 291.59  162.04  201.17]
#  [-690.71  111.49 -612.51]
#  [ 155.5  -531.9  -698.92]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' ' ' 'o']
#  [' ' 'o' 'x']
#
#  [-613.2  -651.91   -2.1 ]
#  [-717.97   -2.29 -865.84]
#  [  -2.56 -522.08 -772.17]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['x' ' ' 'o']
#  ['o' 'o' 'x']
#
#  [-1003.15 -1000.36  -999.95]
#  [-1002.11    -4.55 -1001.58]
#  [-1002.7  -1002.85 -1000.34]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#
#  [ 455.2   320.23 -639.94]
#  [ 349.22 -637.25  402.4 ]
#  [ 191.3   445.96  340.79]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' 'x' ' ']
#  ['x' ' ' 'o']
#
#  [  89.55  145.41 -820.46]
#  [ 131.07 -817.41  246.29]
#  [-780.79   77.85 -806.05]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['x' 'x' ' ']
#  ['x' ' ' 'o']
#
#  [-681.87  175.17 -455.61]
#  [-679.9  -700.03  358.83]
#  [-667.06  169.53 -632.45]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'o' ' ']
#  [' ' ' ' 'x']
#
#  [-772.59 -791.3    57.7 ]
#  [ 172.26 -771.07  238.74]
#  [ 367.63  195.02 -784.83]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  [' ' 'o' ' ']
#  ['x' ' ' 'x']
#
#  [-515.48 -558.04 -509.75]
#  [ 447.98 -546.39  269.81]
#  [-573.4   527.92 -508.14]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#  ['o' 'x' 'o']
#
#  [-751.13  186.72  208.54]
#  [  73.16  283.13  338.56]
#  [-727.53 -692.67 -682.8 ]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  [' ' ' ' ' ']
#  ['o' 'x' 'o']
#
#  [-866.07 -613.24 -718.68]
#  [  -2.75   -2.65   -2.55]
#  [-409.8  -772.05 -652.01]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['x' 'o' ' ']
#  ['o' 'x' 'o']
#
#  [-1003.52 -1003.47 -1002.95]
#  [-1002.85 -1003.49    -4.79]
#  [-1003.36 -1003.57 -1003.58]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' 'o']
#  [' ' 'x' 'o']
#
#  [ 200.43 -676.47  140.56]
#  [  78.22  420.43 -623.  ]
#  [  94.55 -681.25 -702.23]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' 'o']
#  [' ' 'x' 'o']
#
#  [ 142.56 -596.53  103.19]
#  [-583.31 -517.22 -580.12]
#  [ -18.33 -270.12 -603.97]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['x' 'o' 'o']
#  ['o' 'x' 'o']
#
#  [-415.04 -396.5   801.35]
#  [-465.68 -519.78 -450.83]
#  [-466.02 -434.84 -484.56]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#  [' ' 'o' ' ']
#
#  [ 268.13  191.6   424.98]
#  [ 340.95  321.37 -693.61]
#  [ 170.95 -691.35  318.53]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' 'x']
#  [' ' 'o' ' ']
#
#  [-763.67 -737.58  195.21]
#  [ 195.38  365.57 -790.8 ]
#  [ 277.88 -735.27  264.35]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['o' 'x' 'x']
#  [' ' 'o' ' ']
#
#  [-545.52 -476.05  554.41]
#  [-513.96 -635.26 -436.61]
#  [ 515.25 -600.13  508.04]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  ['o' 'x' 'x']
#  ['x' 'o' ' ']
#
#  [-256.6  -262.43 -260.87]
#  [-253.9  -261.45 -263.98]
#  [-259.55 -265.52  949.71]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' ' ' 'o']
#  [' ' ' ' ' ']
#
#  [ 532.9   365.3  -543.77]
#  [ 229.97  365.21 -539.22]
#  [ 352.82  233.22  201.44]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['x' ' ' 'o']
#  [' ' ' ' ' ']
#
#  [-765.44  148.44 -783.61]
#  [-733.9   221.28 -807.03]
#  [ 166.64  158.28   95.47]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['x' ' ' 'o']
#  ['o' ' ' ' ']
#
#  [-584.87 -388.98 -585.95]
#  [-556.28  422.11 -580.87]
#  [-549.23  117.02   -1.73]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['x' 'x' 'o']
#  ['o' 'o' ' ']
#
#  [-1002.39 -1002.82  -994.49]
#  [ -997.58 -1000.89 -1000.07]
#  [ -999.57 -1001.46    -4.54]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 472.39  174.34 -671.73]
#  [-667.48  327.15  392.9 ]
#  [ 386.45  151.03  190.95]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['x' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [-833.74  257.47 -757.71]
#  [-733.79  158.69   96.19]
#  [  94.85  113.09 -606.88]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['x' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [-554.25  172.01 -645.26]
#  [-452.23 -566.02  358.83]
#  [ 105.08 -679.07 -520.9 ]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['x' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [ -996.94 -1000.68 -1000.68]
#  [-1000.67 -1001.16 -1002.16]
#  [   -4.52 -1002.2  -1000.64]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#
#  [-630.66  369.1   203.99]
#  [ 238.81  375.64  205.18]
#  [ 488.42 -634.94  362.47]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#
#  [-619.25 -597.68  208.08]
#  [  15.38  597.12  196.04]
#  [-669.97 -524.69   27.27]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' 'o' ' ']
#  ['o' 'x' 'x']
#
#  [-733.93 -704.6   -77.54]
#  [ -55.26 -764.08  -70.41]
#  [-796.39 -882.38 -764.45]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#
#  [ 293.05 -610.64  215.9 ]
#  [ 215.49  219.62  226.35]
#  [ 513.32 -622.93  320.39]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' ' ']
#  [' ' 'x' ' ']
#
#  [ 237.31 -688.26 -699.73]
#  [-756.23  128.83  122.19]
#  [ 331.42 -751.37  241.55]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' 'o']
#  ['x' 'x' ' ']
#
#  [ 328.1  -537.15 -601.1 ]
#  [-572.87  545.95 -598.73]
#  [-508.22 -518.79  330.55]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#  [' ' 'o' ' ']
#
#  [ 512.49 -630.87  336.43]
#  [ 206.16  154.62  189.23]
#  [ 192.22 -607.98  216.01]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' ' ' ' ']
#  [' ' 'o' 'o']
#
#  [ 526.45 -678.83 -625.74]
#  [ 147.41  174.01  146.63]
#  [ 183.79 -635.49 -620.87]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' ' ' 'o']
#  ['x' 'o' 'o']
#
#  [ 242.43 -577.05 -655.86]
#  [ 232.42  313.57 -441.86]
#  [-456.38 -691.1  -705.16]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [-568.85  241.8  -569.98]
#  [ 449.12  432.6   294.8 ]
#  [ 516.05  292.33  514.91]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  [' ' ' ' 'x']
#  [' ' 'o' ' ']
#
#  [-742.53  143.39 -695.  ]
#  [ 212.42  375.26 -628.85]
#  [ 173.53 -721.01   86.51]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' ' ' 'x']
#  ['x' 'o' ' ']
#
#  [-442.49   -3.05 -740.87]
#  [-710.63  179.64 -692.4 ]
#  [-722.61 -755.06  129.72]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' 'x' 'x']
#  ['x' 'o' 'o']
#
#  [-1003.4     -4.76 -1003.52]
#  [-1003.57 -1003.29 -1003.52]
#  [-1003.67 -1003.32 -1003.49]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#
#  [ 486.    156.49  280.12]
#  [ 419.4  -616.4   330.89]
#  [ 318.27 -619.2   269.39]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#  ['x' 'o' 'o']
#
#  [ 180.22  150.75  507.58]
#  [ 182.82 -621.57  187.66]
#  [-616.78 -586.27 -569.01]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'x' ' ']
#  ['x' 'o' 'o']
#
#  [-525.69 -527.85  345.15]
#  [ 444.29 -626.    521.48]
#  [-496.2  -590.72 -592.46]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#  [' ' ' ' ' ']
#
#  [ 587.28  319.54  329.74]
#  [-565.05 -570.88  210.15]
#  [ 358.97  371.6   352.17]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['o' 'x' ' ']
#  ['x' ' ' ' ']
#
#  [ 268.21 -573.51  496.86]
#  [-613.75 -591.59  147.94]
#  [-659.31  248.67  185.15]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [-587.24  176.15  523.94]
#  [ 247.26  206.2   378.68]
#  [ 409.07  368.37 -590.61]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' 'x']
#  [' ' 'o' 'x']
#
#  [-651.67  123.54  408.6 ]
#  [ 204.3   131.2  -646.71]
#  [  73.7  -670.35 -317.93]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' 'o' 'x']
#  [' ' 'o' 'x']
#
#  [-460.63 -531.02  230.98]
#  [ 153.3  -543.15 -504.25]
#  [ 101.3  -511.03 -291.61]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['o' 'o' 'x']
#  ['x' 'o' 'x']
#
#  [-348.79 -381.47  889.43]
#  [-359.68 -370.79 -366.02]
#  [-352.72 -352.83 -360.39]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#  ['x' ' ' ' ']
#
#  [ 461.79 -634.17  258.33]
#  [ 446.52  272.53  200.38]
#  [-622.56  542.08  362.  ]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' 'x']
#  ['x' ' ' 'o']
#
#  [ 197.91 -536.46   97.72]
#  [ 268.54  187.15 -539.31]
#  [-632.23   16.75 -720.13]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' 'x']
#  ['x' ' ' 'o']
#
#  [  62.83 -383.86 -220.56]
#  [ 345.74 -429.21 -551.99]
#  [-459.68   52.55 -275.86]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#  [' ' ' ' 'o']
#
#  [ 228.41  170.25  169.55]
#  [ 393.55  392.85 -675.55]
#  [ 200.39  200.96 -683.19]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' 'o' 'x']
#  [' ' ' ' 'o']
#
#  [ 150.18   -4.22    9.76]
#  [-790.17 -768.92 -739.1 ]
#  [  74.      1.7  -720.54]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' 'x']
#  ['o' ' ' 'o']
#
#  [-100.22 -592.24  -96.38]
#  [-679.48 -841.6  -779.38]
#  [-638.58  -96.73 -825.29]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#
#  [ 495.57 -592.66  379.29]
#  [ 160.87 -593.44  189.53]
#  [ 180.26  132.74  198.29]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#
#  [  95.69 -743.53 -706.6 ]
#  [ 147.65 -703.53  149.26]
#  [-732.39  274.82  102.39]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' 'o' 'o']
#  ['x' 'x' ' ']
#
#  [ 151.68 -539.68 -637.91]
#  [ 250.74 -463.23 -639.85]
#  [-534.74 -585.13  371.65]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' 'o' ' ']
#
#  [-533.42  513.64  526.57]
#  [ 376.64  526.66  282.34]
#  [ 494.92 -536.22  552.57]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['o' ' ' 'x']
#  [' ' 'o' ' ']
#
#  [-638.3  -489.34 -613.6 ]
#  [-537.9   140.41 -645.97]
#  [  -2.53 -614.9   285.37]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['o' ' ' 'x']
#  ['o' 'o' 'x']
#
#  [-355.3  -372.89 -377.53]
#  [-348.75  877.68 -338.12]
#  [-342.46 -333.43 -352.81]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#
#  [-423.92 -539.84  320.9 ]
#  [ 620.85 -554.04  328.13]
#  [-551.3   295.63  318.2 ]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'o' 'x']
#  ['x' ' ' 'o']
#
#  [-501.52 -642.37  133.63]
#  [ 345.74 -463.6  -523.35]
#  [-585.11  158.4  -491.61]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' ' ']
#  ['o' 'x' ' ']
#
#  [ 214.61  117.91 -734.9 ]
#  [-742.74  236.54  144.89]
#  [-752.86 -796.28   75.48]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' ' ']
#  ['o' 'x' 'x']
#
#  [ 154.59 -464.11 -398.18]
#  [-562.97   18.56  -13.43]
#  [-406.14 -601.93 -608.56]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [-686.36 -684.99  127.78]
#  [ 198.    424.01  181.46]
#  [ 211.47  339.87  158.07]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [-725.36 -699.6   121.81]
#  [-772.5   337.28  101.62]
#  [-724.36   38.51  143.96]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' 'o' 'x']
#  ['o' ' ' ' ']
#
#  [-826.84 -768.43  173.91]
#  [-712.4  -836.59 -767.88]
#  [-658.46    8.03   84.8 ]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' 'x']
#  [' ' ' ' ' ']
#
#  [-657.98  205.84  335.42]
#  [ 490.47  323.68 -652.35]
#  [ 220.44  211.45  422.26]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [-538.52  139.49   90.72]
#  [-776.99  181.3  -721.34]
#  [ 367.93 -732.06  114.35]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['o' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [-563.02 -460.14 -321.73]
#  [-362.02  384.22 -372.14]
#  [ 258.81 -311.92  203.03]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' 'o']
#  [' ' ' ' ' ']
#
#  [ 426.35  235.38  220.04]
#  [-669.15  175.62 -660.11]
#  [ 443.17  188.49  206.25]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' 'o']
#  [' ' 'x' ' ']
#
#  [ 144.51  126.71 -728.33]
#  [-734.08   61.34 -787.05]
#  [ 135.37 -807.27  278.52]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['x' 'x' 'o']
#  [' ' 'x' ' ']
#
#  [-621.77  304.86 -695.78]
#  [-613.32 -784.56 -561.45]
#  [  81.64 -620.61  148.09]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' 'x']
#  [' ' ' ' ' ']
#
#  [ 304.6   198.62  400.91]
#  [-660.23  224.06 -654.74]
#  [ 214.57  268.19  396.9 ]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' ' ' 'x']
#  [' ' ' ' 'x']
#
#  [ 292.71   97.54 -680.38]
#  [-774.93   82.23 -714.97]
#  [ 276.51  169.54 -629.16]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['o' ' ' 'x']
#  ['x' ' ' 'x']
#
#  [ 470.1  -571.52 -525.08]
#  [-499.15  164.12 -488.5 ]
#  [-570.4   420.43 -544.33]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [-592.27  150.24 -595.39]
#  [ 227.97  336.58  371.33]
#  [ 372.22  210.85  546.08]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' ' ' 'x']
#  [' ' ' ' 'o']
#
#  [-813.96   29.15 -812.15]
#  [ 125.24  239.99 -673.7 ]
#  [ 138.02  103.94 -846.27]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [-570.49 -569.67  263.27]
#  [ 408.33  470.03  269.56]
#  [ 485.03  321.43  502.92]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [-531.3  -502.37 -513.39]
#  [ 285.86  731.1   293.46]
#  [ 371.49  240.4  -484.1 ]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  [' ' ' ' 'o']
#  [' ' 'x' 'x']
#
#  [-613.63 -511.41 -477.69]
#  [ 359.25  357.68 -599.74]
#  [ 454.52 -342.32 -606.05]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#  ['x' ' ' ' ']
#
#  [-624.07  202.77  371.93]
#  [ 208.6   338.23  212.11]
#  [-638.51  479.74  410.87]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' ' ' ' ']
#  ['x' ' ' 'o']
#
#  [-765.86  184.51  163.91]
#  [-810.57  302.25  244.45]
#  [-793.     26.84 -765.56]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' ' ' ' ']
#  ['x' 'o' 'o']
#
#  [-404.8  -477.55  206.26]
#  [-677.98  473.88  182.73]
#  [-536.59 -418.79 -691.12]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['x' ' ' 'x']
#  ['x' 'o' 'o']
#
#  [-354.31 -345.3  -359.19]
#  [-363.72  859.09 -386.81]
#  [-358.13 -351.94 -360.35]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#  [' ' 'x' ' ']
#
#  [ 244.5   306.78  219.92]
#  [ 190.08  372.88 -677.6 ]
#  [ 399.85 -673.97  336.14]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' 'o' 'o']
#  [' ' 'x' ' ']
#
#  [-785.02  193.07  200.7 ]
#  [ 195.1  -737.39 -741.09]
#  [ 267.78 -500.41  132.29]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  [' ' 'o' 'o']
#  ['x' 'x' ' ']
#
#  [-507.41  395.83 -525.81]
#  [ 628.4  -530.79 -526.93]
#  [-564.67 -571.76  553.61]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [ 201.55  192.49  185.47]
#  [-646.86  362.7   449.17]
#  [-646.39  196.5   197.83]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['x' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [-729.05  102.4  -556.96]
#  [-724.56  264.25  182.21]
#  [-712.85  107.66  202.7 ]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [ 575.97  217.83  382.9 ]
#  [-550.7   335.07  339.48]
#  [ 392.95  415.05 -551.49]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [ 326.31  217.89  175.89]
#  [-767.74  211.75  250.5 ]
#  [-741.99 -773.25 -754.64]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [-522.63  315.35 -521.06]
#  [-590.35  677.4   291.58]
#  [-585.01 -532.87 -551.69]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' 'o' 'x']
#
#  [ 593.81  230.84  351.11]
#  [ 231.97  291.36  354.39]
#  [ 194.69 -540.84 -534.58]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [-757.79  123.51   91.32]
#  [  54.75  106.73  221.13]
#  [-547.78 -684.01 -702.61]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' 'o' ' ']
#  ['x' 'o' 'x']
#
#  [-576.18 -523.51  367.37]
#  [  -2.3  -545.8    77.43]
#  [-581.19 -547.24 -508.87]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['x' 'o' ' ']
#  ['x' 'o' 'x']
#
#  [-1002.78 -1002.77 -1003.17]
#  [-1002.51 -1003.15    -4.63]
#  [-1002.49 -1002.9  -1001.07]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' ' ' 'o']
#  [' ' 'x' ' ']
#
#  [ 394.68 -547.45 -564.39]
#  [ 221.7   708.55 -556.71]
#  [ 304.31 -530.77  158.56]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  [' ' ' ' 'o']
#  ['o' 'x' ' ']
#
#  [-517.27 -598.8  -608.68]
#  [ 288.33  486.59 -563.72]
#  [-599.77 -592.33  315.77]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 423.53 -640.95  208.6 ]
#  [-640.38  312.02  373.03]
#  [ 492.6   206.97  240.81]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  ['x' ' ' ' ']
#  ['x' ' ' ' ']
#
#  [-781.68 -851.77  186.02]
#  [-857.19  126.9   102.2 ]
#  [-863.63  179.82  177.78]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'x' 'o']
#  [' ' 'o' ' ']
#
#  [ 370.57  131.79 -714.45]
#  [  84.21 -655.74 -521.48]
#  [ 270.73 -545.85  109.88]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  [' ' 'x' 'o']
#  [' ' 'o' ' ']
#
#  [-602.59 -565.98 -408.32]
#  [ 453.23 -441.38 -515.61]
#  [ 486.59 -614.83  347.37]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['x' 'x' 'o']
#  ['o' 'o' ' ']
#
#  [-273.75 -295.19 -278.4 ]
#  [-298.13 -276.91 -282.56]
#  [-278.42 -302.6   935.92]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 644.32  354.75 -506.43]
#  [-510.21  363.8   433.25]
#  [ 369.53  265.15  364.35]
#
# -------------------------
#
#  ['x' ' ' 'x']
#  ['o' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [-420.79  831.09 -400.09]
#  [-414.08  406.37  401.01]
#  [-448.27  453.13  434.91]
#
# -------------------------
#
#  ['x' ' ' 'x']
#  ['o' 'x' ' ']
#  ['o' 'o' ' ']
#
#  [-588.33  457.9  -583.09]
#  [-489.95 -591.82  420.43]
#  [-535.96 -542.74  597.12]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#
#  [-531.93  564.34  605.85]
#  [ 453.86 -526.29  311.91]
#  [ 414.49  268.24  279.59]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' 'o' ' ']
#  ['x' 'o' ' ']
#
#  [-490.4   266.64  299.9 ]
#  [ 643.11 -530.58  282.01]
#  [-574.02 -582.14  322.27]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' 'x' ' ']
#  [' ' ' ' 'o']
#
#  [-547.08  279.06  191.19]
#  [-526.01 -581.93  657.25]
#  [ 201.32  259.81 -526.97]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['x' 'x' ' ']
#  ['o' ' ' 'o']
#
#  [-477.25  353.51 -565.59]
#  [-647.72 -521.62  506.93]
#  [-431.88  496.37 -610.37]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' 'x' 'x']
#  [' ' 'o' ' ']
#
#  [-543.12  166.1   162.72]
#  [ 358.83 -690.18 -520.04]
#  [  99.67 -489.31  133.77]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' 'x' 'x']
#  ['x' 'o' 'o']
#
#  [-543.73  311.44  171.74]
#  [ 346.25 -440.28 -471.91]
#  [-533.25 -399.   -571.43]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['o' ' ' ' ']
#  ['x' ' ' ' ']
#
#  [-550.35  153.7  -576.16]
#  [-610.57  554.41  244.75]
#  [-591.03  256.49  270.14]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['o' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [-629.64 -656.46 -530.32]
#  [-656.45  465.43 -524.09]
#  [-633.07  319.23  265.54]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#
#  [ 558.33  179.14 -569.5 ]
#  [ 217.7   315.62  173.6 ]
#  [ 387.17  350.   -569.32]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [ 486.59   88.34 -588.78]
#  [ 140.89 -685.06  146.97]
#  [  26.12 -658.5  -618.39]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' 'x' ' ']
#  ['x' 'o' 'x']
#
#  [ 264.26  144.3  -488.87]
#  [-720.55 -542.73  102.18]
#  [-501.94 -589.03 -483.21]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['o' 'x' 'x']
#  ['x' 'o' 'x']
#
#  [ -995.8     -4.34  -994.34]
#  [-1001.36 -1001.06 -1000.08]
#  [ -994.23  -999.41  -992.05]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 562.1  -597.74  382.4 ]
#  [-604.44  376.47  180.63]
#  [ 195.78  321.41  208.18]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  ['o' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [ 535.92 -605.79 -305.14]
#  [-571.6   239.92  180.55]
#  [-480.38   94.45  205.77]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#
#  [ 116.88 -722.31 -764.63]
#  [-697.13 -724.56  104.13]
#  [ 105.53  243.5    62.93]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' 'o' 'x']
#  ['o' ' ' ' ']
#
#  [ 120.33 -666.05 -421.76]
#  [-677.35 -711.89 -482.89]
#  [-463.52   38.14  278.34]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['x' 'o' 'x']
#  ['o' 'x' ' ']
#
#  [-329.08 -306.18 -315.91]
#  [-302.42 -312.3  -310.99]
#  [-344.26 -310.17  909.66]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#  [' ' 'x' ' ']
#
#  [ 306.64  372.87  270.97]
#  [-548.92  388.15  273.7 ]
#  [ 584.14 -561.09  486.85]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [ 162.39  198.18  103.  ]
#  [-712.6   356.38 -749.84]
#  [ 164.46 -708.25 -753.93]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' 'x']
#  ['o' 'x' 'o']
#
#  [-473.28  602.7   219.17]
#  [-504.83  112.61 -543.63]
#  [-573.91 -531.93 -392.29]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['o' 'o' 'x']
#  ['o' 'x' 'o']
#
#  [-286.82 -277.89  929.1 ]
#  [-280.06 -276.28 -273.85]
#  [-279.97 -298.38 -273.26]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [ 261.63 -568.92   80.24]
#  [  87.67  162.05   41.06]
#  [-704.83 -788.13 -809.56]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' 'x' ' ']
#  ['x' 'o' 'x']
#
#  [-561.6  -563.33  384.22]
#  [ 114.65 -653.27  204.03]
#  [-631.14 -615.84 -335.37]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' ' ' ' ']
#  [' ' 'x' 'x']
#
#  [ 352.05  138.75 -630.73]
#  [-641.83  215.05  114.38]
#  [ 597.12 -651.44 -603.5 ]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['o' ' ' ' ']
#  [' ' 'x' 'x']
#
#  [-650.44 -538.14 -644.21]
#  [-416.75  420.43  110.79]
#  [ 253.57 -562.59 -474.76]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#  ['x' ' ' ' ']
#
#  [ 308.88  212.88  383.7 ]
#  [-533.69  403.37  222.02]
#  [-537.91  554.8   358.17]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' ' ' 'x']
#  ['x' ' ' ' ']
#
#  [-686.03  286.52  157.86]
#  [-775.45  162.45 -667.06]
#  [-642.48  412.11  268.99]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['o' ' ' 'x']
#  ['x' 'o' ' ']
#
#  [-584.97  542.96 -462.76]
#  [-517.94  220.27 -569.68]
#  [-473.62 -562.99  327.38]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' ' ']
#  [' ' 'o' ' ']
#
#  [ 384.75  207.08  178.39]
#  [-652.77  368.46  351.45]
#  [ 465.08 -645.4   229.82]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['x' ' ' ' ']
#  [' ' 'o' 'o']
#
#  [-620.97  281.92  337.58]
#  [-629.34  243.86  246.15]
#  [ 580.51 -612.15 -619.44]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 273.77 -665.22 -670.26]
#  [ 201.04  307.17  419.67]
#  [ 294.15  218.53  334.82]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'o' ' ']
#  [' ' 'x' ' ']
#
#  [ 131.49 -673.95 -715.7 ]
#  [ 105.49 -434.01  156.37]
#  [ 110.92 -773.82  376.59]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  [' ' 'o' ' ']
#  ['o' 'x' ' ']
#
#  [-625.35 -671.05 -673.42]
#  [  -2.96 -619.8   351.22]
#  [-698.96 -681.25  285.91]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['o' 'o' 'x']
#  ['o' 'x' ' ']
#
#  [-225.21 -227.06 -224.47]
#  [-228.75 -225.36 -224.91]
#  [-229.06 -228.49  980.15]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' 'x']
#  [' ' ' ' 'o']
#
#  [-747.04  234.9   409.18]
#  [-634.44  123.1  -733.46]
#  [ 155.7   189.49 -711.02]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' 'x' 'x']
#  [' ' ' ' 'o']
#
#  [-675.37  365.69 -583.64]
#  [-654.45 -654.36 -684.15]
#  [  -2.84  304.14 -652.13]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  ['o' 'x' 'x']
#  ['x' ' ' 'o']
#
#  [-1003.69 -1003.69 -1003.79]
#  [-1003.74 -1003.75 -1003.61]
#  [-1003.76    -4.84 -1003.76]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' 'x']
#  ['o' ' ' ' ']
#
#  [ 280.2   176.3   425.69]
#  [ 459.51  371.56 -664.36]
#  [-663.13  195.84  398.03]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  [' ' ' ' 'x']
#  ['o' 'x' ' ']
#
#  [-756.03   56.82  108.76]
#  [ 267.52  139.1  -810.84]
#  [-772.87 -838.11   44.61]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' ' ' 'x']
#  ['o' 'x' 'x']
#
#  [-592.24 -428.55  184.66]
#  [  87.07  -12.91 -537.04]
#  [-450.26 -432.85 -489.7 ]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [-502.62  570.14  614.27]
#  [-484.41  585.93  304.8 ]
#  [ 309.93  308.45  537.08]
#
# -------------------------
#
#  ['x' ' ' 'x']
#  ['o' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [-461.18  827.59 -451.96]
#  [-437.91  366.07  360.66]
#  [ 376.8   363.94 -417.1 ]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['o' ' ' ' ']
#  [' ' 'x' 'o']
#
#  [-617.97 -606.64 -786.34]
#  [-749.65   60.64   -2.7 ]
#  [ 324.09 -525.34 -510.73]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['o' 'x' 'o']
#  [' ' 'x' 'o']
#
#  [-234.48 -239.78 -237.95]
#  [-242.99 -241.33 -240.32]
#  [ 969.03 -250.87 -239.05]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#
#  [ 489.78 -600.19  315.01]
#  [ 314.09 -601.8   400.72]
#  [ 273.4   212.38  331.62]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' 'x' ' ']
#  ['x' ' ' ' ']
#
#  [-610.39 -600.49  486.59]
#  [ 211.53 -603.57  173.2 ]
#  [-549.69  202.42  129.39]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#  [' ' 'o' 'x']
#
#  [ 375.7  -658.95  196.32]
#  [ 264.42 -602.77  105.12]
#  [ 103.22 -449.92 -692.43]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['o' 'o' 'x']
#  [' ' 'o' 'x']
#
#  [ 175.53 -550.35  101.63]
#  [-626.64 -599.04 -543.58]
#  [ 293.12 -564.99 -586.58]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' 'x']
#  [' ' ' ' ' ']
#
#  [ 268.93 -647.21  403.69]
#  [ 375.3   377.89 -649.81]
#  [ 208.17  207.73  332.41]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' 'o' 'x']
#  [' ' ' ' ' ']
#
#  [  31.37 -810.04   55.9 ]
#  [-778.6  -757.96 -661.32]
#  [  20.94   46.22  197.94]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  ['x' 'o' 'x']
#  [' ' ' ' 'x']
#
#  [-635.33 -533.91  456.62]
#  [-653.48 -640.37 -705.21]
#  [ 196.66  311.86 -664.36]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#
#  [  51.29 -764.18 -767.22]
#  [ 145.52 -780.51   63.47]
#  [-723.72  172.1    63.15]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  [' ' 'o' ' ']
#  ['x' ' ' 'o']
#
#  [-612.7  -599.64 -490.87]
#  [ 486.59 -616.35   82.58]
#  [-589.43  279.99 -539.52]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'x' ' ']
#  ['o' ' ' ' ']
#
#  [ 534.47  417.65  222.66]
#  [ 410.63 -589.03  364.27]
#  [-581.99  488.44  328.3 ]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'x' ' ']
#  ['o' ' ' 'o']
#
#  [ 256.52 -494.12   98.81]
#  [ 234.69 -655.49  166.22]
#  [-490.32  496.86 -684.8 ]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  [' ' 'x' 'o']
#  ['o' ' ' 'o']
#
#  [-653.77 -436.06  339.85]
#  [ 229.6  -616.72 -458.16]
#  [-553.1   461.91 -336.27]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#
#  [-509.19 -492.97  227.38]
#  [ 227.73 -524.79  355.09]
#  [ 263.48 -500.4   719.95]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' 'o' 'x']
#  [' ' 'x' ' ']
#
#  [ 211.14 -785.5    86.89]
#  [  72.55 -739.68 -780.81]
#  [ 140.28 -631.33  170.28]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' 'o' 'x']
#  ['x' 'x' ' ']
#
#  [-531.09 -364.32  202.51]
#  [  71.35 -665.24 -710.35]
#  [-600.15 -648.    286.48]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#  [' ' 'x' 'o']
#
#  [ 257.49  597.12  312.64]
#  [-617.1  -595.56  314.37]
#  [ 325.97 -602.38 -553.95]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' 'x']
#  ['o' 'x' 'o']
#
#  [ 123.94  345.74  129.26]
#  [-524.86 -627.78 -739.2 ]
#  [-674.26 -497.96 -624.98]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['o' 'x' 'x']
#  ['o' 'x' 'o']
#
#  [-1002.79 -1003.55    -4.8 ]
#  [-1003.03 -1003.22 -1003.67]
#  [-1003.71 -1003.63 -1003.29]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [-662.46 -638.06  244.67]
#  [ 554.75  234.41 -648.49]
#  [-669.07  329.85  256.25]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['o' ' ' 'o']
#  ['x' ' ' 'x']
#
#  [-531.11 -496.17  394.81]
#  [-594.69  495.38 -562.95]
#  [-561.45  545.2  -556.19]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' 'x']
#  [' ' ' ' ' ']
#
#  [ 252.69 -624.63 -588.08]
#  [-624.18  545.2  -597.11]
#  [ 243.13  190.83  174.64]
#
# -------------------------
#
#  ['x' 'o' 'o']
#  ['x' 'o' 'x']
#  [' ' ' ' ' ']
#
#  [-531.97 -643.88 -488.84]
#  [-526.93 -682.04 -600.17]
#  [ 432.02  105.31  234.66]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' 'o']
#
#  [ 257.53  343.41  185.95]
#  [ 180.99  511.72  212.88]
#  [ 191.18 -614.14 -620.22]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' ' ' ' ']
#  [' ' 'x' 'o']
#
#  [-756.19  175.81 -680.19]
#  [ 223.31  316.33  160.52]
#  [ 174.33 -773.91 -704.23]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['o' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [-814.46  106.88 -820.75]
#  [-744.34  275.51 -704.35]
#  [ 295.18 -832.51 -764.1 ]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [ 517.14 -643.29 -596.54]
#  [ 155.88 -549.82  141.76]
#  [-591.28  138.2   172.62]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['x' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [-462.44 -587.89 -559.21]
#  [-789.05 -724.96  132.79]
#  [-689.37   65.37  259.88]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' 'x' ' ']
#  [' ' 'o' 'o']
#
#  [-730.44   45.36  248.15]
#  [ 206.5  -768.82  147.42]
#  [ 327.41 -765.18 -715.84]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['x' 'x' ' ']
#  [' ' 'o' 'o']
#
#  [-716.12  107.2  -601.92]
#  [-566.76 -544.56  225.69]
#  [ 334.52 -657.95 -549.17]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'x' ' ']
#  ['o' 'o' ' ']
#
#  [ 139.19   80.43 -745.67]
#  [ 104.19 -806.2   245.85]
#  [-819.28 -802.11  136.38]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  [' ' 'x' ' ']
#  ['o' 'o' ' ']
#
#  [-809.55 -532.3  -701.69]
#  [ -47.88 -662.    -73.68]
#  [-790.01 -668.07  -64.38]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' 'x']
#  [' ' ' ' 'o']
#
#  [ 185.62  258.15  154.11]
#  [-800.19 -794.79 -809.86]
#  [ 289.57  306.3  -813.73]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['o' 'x' 'x']
#  [' ' ' ' 'o']
#
#  [-564.42 -567.49  207.76]
#  [-567.95 -570.47 -600.75]
#  [ 603.09  395.95 -548.96]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  [' ' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [-474.08 -426.1   780.24]
#  [ 413.99 -429.33  437.76]
#  [-431.96  449.17  420.43]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['o' 'o' ' ']
#  ['o' ' ' 'x']
#
#  [-672.39 -498.56  516.79]
#  [-558.13 -642.83  326.17]
#  [-643.95  256.13 -653.1 ]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [ 344.48  139.7   204.16]
#  [-624.75  374.24  423.45]
#  [ 442.24  209.   -627.12]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [ 174.41 -711.84 -737.89]
#  [-597.92  189.28  127.35]
#  [ 182.15  184.39 -827.82]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['x' 'o' ' ']
#  [' ' ' ' 'o']
#
#  [-644.55 -621.1  -667.84]
#  [-631.83 -566.94  196.57]
#  [ 486.59  172.09 -592.26]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['x' 'o' 'x']
#  ['o' ' ' 'o']
#
#  [-997.82 -977.59 -997.27]
#  [-986.4  -974.88 -984.54]
#  [-988.02   -4.12 -990.79]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#  ['x' ' ' 'o']
#
#  [ 284.89 -774.9   151.92]
#  [ 153.35 -701.84  109.54]
#  [-754.12   24.2  -690.71]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' ' ' ' ']
#  ['x' 'x' ' ']
#
#  [-467.01  261.45  344.36]
#  [-465.28  405.44  390.84]
#  [-455.77 -461.26  766.59]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' 'o' 'x']
#  ['x' 'x' ' ']
#
#  [-568.88  299.76  498.2 ]
#  [-438.61 -518.34 -588.03]
#  [-580.23 -653.46  316.2 ]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['o' 'o' 'x']
#  ['x' 'x' ' ']
#
#  [-249.07 -253.19 -251.57]
#  [-266.9  -247.65 -247.66]
#  [-251.31 -256.47  959.73]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [-531.52  563.05  608.14]
#  [ 205.18  524.23  313.99]
#  [-522.01  289.48  550.11]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['x' ' ' ' ']
#  ['o' 'o' ' ']
#
#  [-777.4   177.46  241.08]
#  [-780.76  209.67  179.16]
#  [-794.91 -788.55  307.8 ]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#
#  [ 530.21 -600.51  311.43]
#  [ 190.25  371.64  165.67]
#  [-604.56  372.15  212.53]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  [' ' ' ' ' ']
#  ['o' 'o' ' ']
#
#  [-479.81 -487.66  714.23]
#  [ 298.84  335.59  264.67]
#  [-523.52 -508.98  357.37]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  [' ' ' ' ' ']
#  ['o' 'o' 'x']
#
#  [-635.59 -644.08 -634.09]
#  [ 383.6   486.59  276.23]
#  [-618.71 -605.09 -644.33]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' 'x' ' ']
#  [' ' 'o' ' ']
#
#  [-512.06  253.16  269.21]
#  [-551.1  -531.17  708.4 ]
#  [ 265.47 -508.96  301.1 ]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' 'x' ' ']
#  ['o' 'o' ' ']
#
#  [-618.94 -671.31  243.16]
#  [-582.96 -608.26  526.45]
#  [-647.28 -622.68  178.11]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [ 443.38   94.58   81.63]
#  [-509.28 -736.83  116.79]
#  [ 124.48 -627.84 -585.32]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['o' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [-796.43 -658.57   52.95]
#  [-840.22 -680.69   13.22]
#  [  81.97 -667.08 -599.37]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['o' 'x' 'o']
#  ['x' 'o' 'x']
#
#  [-405.25 -381.77  861.91]
#  [-431.7  -414.71 -373.87]
#  [-402.32 -383.24 -423.14]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['o' 'x' ' ']
#  [' ' ' ' 'x']
#
#  [-753.43  222.3   329.32]
#  [-765.51 -736.71  135.04]
#  [ 249.7   227.41 -757.37]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' ' ' 'o']
#  [' ' ' ' ' ']
#
#  [-536.05  539.97  608.93]
#  [ 369.78  541.91 -533.59]
#  [ 468.23  284.53  529.46]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' 'o']
#  [' ' 'x' ' ']
#
#  [-720.53  319.7   359.47]
#  [-721.81  444.44 -693.13]
#  [ 280.37 -726.23  293.43]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'o' ' ']
#  [' ' 'x' ' ']
#
#  [ 249.13  135.79  218.89]
#  [ 153.51 -648.77  187.11]
#  [ 453.8  -646.45  376.79]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' 'o' 'x']
#  [' ' 'x' ' ']
#
#  [  30.9    55.46 -647.36]
#  [  36.34 -688.11 -669.53]
#  [ 156.52 -674.91  125.76]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  [' ' ' ' 'o']
#  [' ' 'x' 'x']
#
#  [ 219.09  130.47 -585.39]
#  [ 214.83  113.64 -537.99]
#  [ 420.62 -612.6  -630.35]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' ' ' 'o']
#  ['o' 'x' 'x']
#
#  [  80.37 -239.98 -568.53]
#  [ 184.21  206.69 -305.78]
#  [-576.27 -456.73 -477.82]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['x' ' ' 'o']
#  ['o' 'x' 'x']
#
#  [-349.89 -351.35 -367.48]
#  [-336.96  882.52 -348.51]
#  [-343.53 -333.19 -357.05]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [-765.37 -689.11  243.73]
#  [ 164.2   144.48 -687.94]
#  [ 150.33 -766.46   65.39]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['o' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [-434.83 -492.75 -306.67]
#  [-409.91  319.23 -266.44]
#  [ 445.47 -460.5   204.31]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' ' ']
#  [' ' 'o' 'x']
#
#  [-399.71  304.85  309.73]
#  [-380.89  850.29  346.64]
#  [ 367.62 -399.59 -372.07]
#
# -------------------------
#
#  ['x' ' ' 'x']
#  ['o' 'o' ' ']
#  [' ' 'o' 'x']
#
#  [-677.27  419.97 -659.67]
#  [-589.53 -658.33  454.76]
#  [ 177.97 -625.25 -611.25]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'o' 'x']
#  [' ' ' ' ' ']
#
#  [ 285.36  195.84  403.84]
#  [ 143.93 -663.67 -668.22]
#  [ 174.28  170.27  334.7 ]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  [' ' 'o' 'x']
#  [' ' ' ' 'o']
#
#  [-753.1   267.66  252.96]
#  [ 111.23 -796.8  -712.45]
#  [ 272.95  232.34 -650.15]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['x' 'o' 'x']
#  [' ' 'o' 'o']
#
#  [-669.55  186.23  204.45]
#  [-554.16 -551.05 -609.65]
#  [ 396.54 -531.73 -682.79]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['x' 'o' 'x']
#  [' ' 'o' 'o']
#
#  [-383.19 -346.36 -375.97]
#  [-357.82 -421.41 -386.68]
#  [ 861.91 -401.67 -365.92]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [ 269.64  324.82 -573.31]
#  [-672.64  581.52 -607.39]
#  [-608.5   266.23  216.35]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  ['o' ' ' 'o']
#  ['x' ' ' 'x']
#
#  [-533.39  296.69 -574.76]
#  [-620.95  476.96 -636.56]
#  [-513.4   376.21 -631.46]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' 'o']
#
#  [-754.5  -775.54   99.69]
#  [ 175.35  195.29   80.8 ]
#  [ 367.9  -718.85 -722.04]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [-598.99 -549.2   589.17]
#  [ 628.45  406.06 -591.31]
#  [-576.96 -554.1  -594.91]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['o' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [-268.27 -282.32 -267.66]
#  [-289.35  949.71 -283.5 ]
#  [-281.98 -271.98 -269.83]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' ' ' 'x']
#  ['o' ' ' ' ']
#
#  [-547.34  131.45  245.7 ]
#  [-536.65  720.07 -530.96]
#  [-519.45  238.96  294.84]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['x' ' ' 'x']
#  ['o' ' ' ' ']
#
#  [-463.98 -534.47 -524.01]
#  [-596.96  149.84 -551.13]
#  [-551.46  373.84  312.87]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' 'o']
#
#  [ 499.01 -641.11  383.36]
#  [ 150.54  262.82  168.28]
#  [ 200.25  308.81 -664.19]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' 'o']
#
#  [-490.77 -595.13  149.81]
#  [ 182.26  384.29  201.76]
#  [ 177.22 -706.68 -717.78]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' ' ' 'x']
#  [' ' ' ' 'x']
#
#  [-580.87 -624.68  371.65]
#  [ 185.76  219.09 -597.94]
#  [ 210.51  129.26 -657.35]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  ['o' ' ' 'x']
#  [' ' 'x' 'x']
#
#  [-517.96 -378.12  132.67]
#  [-322.8   140.71 -585.94]
#  [ 358.83 -576.59 -413.13]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  [' ' 'x' 'o']
#  [' ' ' ' ' ']
#
#  [ 532.35  346.67  356.02]
#  [ 149.67 -580.84 -576.33]
#  [ 280.28  370.96  291.57]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' 'x' 'o']
#  ['o' 'o' ' ']
#
#  [ 318.77 -663.89 -605.37]
#  [  78.03 -572.72 -642.17]
#  [-479.39 -468.82  266.02]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' 'x']
#  [' ' 'o' ' ']
#
#  [-749.33  148.01  412.85]
#  [-787.03  226.29 -699.95]
#  [ 208.69 -726.86  259.74]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' ' ' 'x']
#  ['x' 'o' 'o']
#
#  [-554.32  138.89  554.28]
#  [-619.55  237.88 -382.1 ]
#  [-590.29 -569.96 -605.31]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' ' ' 'x']
#  ['o' ' ' 'o']
#
#  [  53.1  -834.8    97.24]
#  [  84.67  184.83 -643.26]
#  [-748.17   54.03 -769.76]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  [' ' ' ' 'x']
#  ['o' ' ' 'o']
#
#  [-686.44 -717.06 -640.15]
#  [  39.12  228.45 -670.98]
#  [-665.16  165.68 -329.85]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['o' ' ' 'x']
#  ['o' 'x' 'o']
#
#  [-368.54 -385.6  -377.5 ]
#  [-370.91  872.63 -371.53]
#  [-382.56 -380.01 -389.61]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#  ['o' ' ' 'x']
#
#  [ 476.18  175.74  217.08]
#  [-623.8  -608.5   125.84]
#  [-564.8   191.72 -641.6 ]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' 'x' 'x']
#  ['o' ' ' 'x']
#
#  [ 465.63  223.23 -574.95]
#  [-638.11 -471.1  -482.86]
#  [-603.5   278.93 -568.43]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' 'x' ' ']
#  ['o' 'x' ' ']
#
#  [ 195.39  589.1   301.47]
#  [-585.11 -639.74  266.3 ]
#  [-637.77 -695.12  293.24]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' 'x' 'o']
#  ['o' 'x' ' ']
#
#  [ 344.9   465.43 -604.15]
#  [-593.66 -507.61 -607.55]
#  [-434.55 -501.81  286.53]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' ' ' ' ']
#  ['x' ' ' 'o']
#
#  [ 288.77 -670.11 -656.82]
#  [ 187.88  409.     60.59]
#  [-556.06   93.37 -587.77]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' ' ']
#  ['o' 'x' 'x']
#
#  [ 356.07   85.69  156.98]
#  [-768.98  189.51  192.05]
#  [-782.14 -772.42 -716.25]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' ' ' ' ']
#  ['o' 'x' 'x']
#
#  [-635.74  337.83 -658.6 ]
#  [-592.38  563.21  323.32]
#  [-598.74 -636.62 -610.9 ]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  [' ' 'o' ' ']
#  ['x' ' ' ' ']
#
#  [-770.29 -759.88   99.58]
#  [  76.35 -769.97  110.92]
#  [-812.8   161.46  287.17]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' 'o' ' ']
#  ['x' 'o' ' ']
#
#  [-880.04 -913.06  -48.44]
#  [-892.29 -892.1   -46.58]
#  [-834.73 -866.65   -3.42]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [  70.76 -582.56  158.47]
#  [-826.73 -736.55   17.93]
#  [-673.69   26.24  103.62]
#
# -------------------------
#
#  ['x' 'x' ' ']
#  ['x' 'o' ' ']
#  ['o' 'o' ' ']
#
#  [-383.4  -638.67  420.43]
#  [-530.24 -539.26  213.19]
#  [-624.51 -524.04  314.38]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' ' ' ' ']
#  ['x' 'x' ' ']
#
#  [ 207.11 -422.98 -521.13]
#  [ 296.14  231.35  292.53]
#  [-578.94 -577.14  613.08]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'o' 'x']
#  ['x' 'x' ' ']
#
#  [ 470.12 -445.3  -458.91]
#  [ 169.92 -466.31 -588.16]
#  [-529.16 -647.61  348.2 ]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [-676.96  122.52  234.5 ]
#  [-791.5   134.68 -817.16]
#  [-728.43  319.63  142.31]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' ' ' 'o']
#  ['x' 'o' 'x']
#
#  [-484.23   -2.57   69.71]
#  [-701.33  491.84 -570.68]
#  [-502.36 -653.54 -562.19]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  ['x' ' ' 'o']
#  ['x' 'o' 'x']
#
#  [ -999.04 -1001.55  -997.59]
#  [ -997.92    -4.5  -1000.31]
#  [ -999.16  -996.99  -999.63]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' ' ' ' ']
#  [' ' 'x' 'x']
#
#  [-669.75 -603.97  209.78]
#  [ 177.17  210.38  170.62]
#  [ 506.93 -624.72 -562.22]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  [' ' ' ' 'o']
#  [' ' 'x' 'x']
#
#  [-698.12 -514.89 -682.72]
#  [ 125.86  280.97 -703.05]
#  [ 420.43 -538.63 -571.02]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  [' ' 'x' 'o']
#  ['o' 'x' 'x']
#
#  [ -998.87 -1001.59  -998.  ]
#  [   -4.28  -977.81 -1001.7 ]
#  [-1000.42  -997.31  -996.7 ]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [ 344.53 -768.12 -591.71]
#  [ 134.99   73.   -688.09]
#  [ 100.45 -838.89   97.59]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'o' 'x']
#  [' ' 'x' 'x']
#
#  [ 254.11 -600.14 -660.83]
#  [  87.9  -567.46 -608.67]
#  [ 408.6  -497.17 -394.22]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['o' ' ' 'x']
#  ['o' 'x' ' ']
#
#  [ 406.54  141.81  161.17]
#  [-683.8   142.8  -712.36]
#  [-697.25 -716.44  221.12]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['o' 'o' 'x']
#  ['o' 'x' ' ']
#
#  [-573.42  396.4   724.59]
#  [-505.93 -507.12 -501.51]
#  [-515.06 -534.86  337.32]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['o' 'o' 'x']
#  ['o' 'x' 'x']
#
#  [-309.32 -329.35  914.97]
#  [-331.45 -341.31 -315.11]
#  [-360.72 -320.14 -317.26]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  [' ' 'o' 'x']
#  [' ' ' ' ' ']
#
#  [-717.81  229.36 -745.98]
#  [ 237.11 -707.59 -739.48]
#  [ 465.83  258.32  114.17]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' 'x' ' ']
#  [' ' ' ' 'o']
#
#  [-551.59  220.72 -620.75]
#  [ 261.75 -643.99  177.41]
#  [ 465.43  258.3  -625.29]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' ' ']
#  [' ' ' ' 'x']
#
#  [ 486.59 -506.75 -479.05]
#  [ 216.49 -520.9   189.15]
#  [ 177.12  159.13 -208.49]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'x' 'o']
#  ['o' ' ' ' ']
#
#  [ 306.25 -666.82  155.37]
#  [ 189.95 -632.22 -646.6 ]
#  [-569.72  443.4   104.38]
#
# -------------------------
#
#  ['o' 'x' ' ']
#  ['x' 'x' 'o']
#  ['o' ' ' ' ']
#
#  [-674.4  -684.15  181.55]
#  [-667.86 -669.83 -674.26]
#  [-637.5   506.93  223.66]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [   8.86 -567.17  112.07]
#  [ 150.47  118.27 -668.5 ]
#  [  56.5  -691.55 -646.85]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' 'o' 'x']
#  [' ' 'x' 'o']
#
#  [ 143.06 -324.79  -12.3 ]
#  [-549.24 -494.59 -595.76]
#  [  74.48 -557.95 -532.09]
#
# ...
#  [' ' ' ' 'o']
#
#  [-470.35 -557.08 -543.1 ]
#  [ 356.22 -587.88 -535.48]
#  [ 606.7   332.   -413.62]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' 'o' ' ']
#  ['x' 'x' 'o']
#
#  [ -61.26  -80.98 -860.06]
#  [-793.84 -876.92  -63.9 ]
#  [-704.34 -800.58 -711.75]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' 'x' ' ']
#  ['x' 'x' 'o']
#
#  [ 100.44  451.69 -662.93]
#  [-616.3  -609.01  429.4 ]
#  [-463.58 -564.   -538.35]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['x' 'o' ' ']
#  ['o' 'x' 'o']
#
#  [  88.42   61.83 -494.6 ]
#  [-336.83 -265.2    -1.76]
#  [-507.21 -258.71 -261.18]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['o' ' ' 'x']
#  ['x' ' ' 'o']
#
#  [  -2.67 -375.37 -530.49]
#  [-390.88  250.3  -516.37]
#  [-506.13  137.87 -624.4 ]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' 'o' ' ']
#  [' ' ' ' 'x']
#
#  [ 112.43 -782.06  143.05]
#  [-792.5  -623.33  149.21]
#  [  46.41   98.88 -822.25]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  [' ' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [-628.33 -417.22 -591.99]
#  [ 231.5   397.05 -602.88]
#  [ 281.28 -647.22 -626.44]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' ' ' 'x']
#  ['o' 'x' 'o']
#
#  [ 195.2  -584.16 -597.81]
#  [  77.13  294.27 -694.4 ]
#  [-715.07 -673.14 -603.8 ]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' 'x' 'o']
#  ['x' ' ' 'x']
#
#  [ 332.39  220.23 -464.28]
#  [-596.46 -435.82 -614.33]
#  [-600.92  283.6  -584.  ]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['o' ' ' 'x']
#  ['o' 'x' 'x']
#
#  [ 150.84   40.3  -592.25]
#  [-372.02   57.16 -377.57]
#  [-382.58 -310.42 -624.92]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' ' ']
#  ['x' 'x' 'o']
#
#  [ -31.   -416.43 -579.81]
#  [ -68.65 -579.33  -38.41]
#  [-578.28 -578.02 -665.33]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' 'o']
#  ['x' ' ' 'x']
#
#  [  72.79 -634.08 -474.79]
#  [-381.09   95.41 -379.76]
#  [-610.54  246.36 -563.01]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'o' 'x']
#  ['x' 'o' 'o']
#
#  [ 123.87   93.69 -480.48]
#  [   5.23 -498.9  -442.79]
#  [-686.5  -492.14 -574.47]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  [' ' 'o' 'x']
#  ['o' 'x' ' ']
#
#  [-697.19 -653.57  287.48]
#  [  76.19 -666.25 -592.46]
#  [-660.87 -675.49  203.41]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  ['x' 'o' 'o']
#  [' ' 'o' 'x']
#
#  [-1.10e-01 -1.90e+02 -1.00e+02]
#  [-1.00e+02  0.00e+00 -1.00e+02]
#  [ 0.00e+00  0.00e+00 -2.71e+02]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  ['o' ' ' 'o']
#  [' ' ' ' 'x']
#
#  [   1.59    0.   -100.  ]
#  [   0.      0.   -189.76]
#  [   0.     -9.77    0.  ]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' 'x']
#  ['o' 'o' 'x']
#
#  [   0.  -190.    39.6]
#  [ -98.4    0.  -100. ]
#  [   0.  -188.4    0. ]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['x' 'x' ' ']
#  [' ' 'o' ' ']
#
#  [   0.    -10.01    0.  ]
#  [-100.   -100.    -18.12]
#  [   0.      0.      0.  ]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['x' 'x' 'o']
#  [' ' ' ' ' ']
#
#  [-190.      0.      0.  ]
#  [   0.      0.      0.  ]
#  [   0.    -10.01    0.  ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [ -10.01 -100.      0.  ]
#  [   0.      0.      0.  ]
#  [   0.      0.      0.  ]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' ' ' ' ']
#  ['o' 'x' 'o']
#
#  [  0.     0.     0.  ]
#  [-10.01   0.     0.  ]
#  [  0.     0.     0.  ]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [-1.0e-02  0.0e+00 -1.9e+02]
#  [-1.0e-02  0.0e+00  0.0e+00]
#  [ 0.0e+00 -1.0e+02  0.0e+00]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' 'x']
#  ['x' ' ' 'o']
#
#  [ 2.00e+01  0.00e+00 -1.00e-02]
#  [-1.00e-02 -9.84e+01 -9.84e+01]
#  [ 0.00e+00  0.00e+00  0.00e+00]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' 'x']
#  ['o' 'x' ' ']
#
#  [  -5.5     0.   -189.29]
#  [   0.      0.   -100.  ]
#  [-270.29 -189.29    0.  ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' ' ' 'o']
#  ['x' 'o' 'x']
#
#  [ 0.  0.  0.]
#  [ 0. 20.  0.]
#  [ 0.  0.  0.]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  [' ' 'o' 'o']
#  [' ' 'x' 'x']
#
#  [-3.3956e+02 -1.0000e+02 -9.8400e+01]
#  [ 3.9600e+01 -9.8400e+01 -9.8400e+01]
#  [-2.0000e-01  0.0000e+00 -9.8400e+01]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  [' ' 'x' 'x']
#  ['x' ' ' ' ']
#
#  [ 0.00e+00  0.00e+00  0.00e+00]
#  [ 4.69e+00 -1.00e+02  0.00e+00]
#  [ 0.00e+00 -1.00e-02  0.00e+00]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' 'x' 'x']
#  ['o' ' ' ' ']
#
#  [   0.      0.      0.  ]
#  [   0.      0.      0.  ]
#  [-271.    -10.01    0.  ]
#
# -------------------------
#
#  ['x' 'o' ' ']
#  ['x' 'o' 'x']
#  [' ' ' ' ' ']
#
#  [   0.      0.      0.  ]
#  [   0.      0.   -100.  ]
#  [   4.69    0.      0.  ]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' 'x']
#  ['o' ' ' 'x']
#
#  [   0.      0.      0.  ]
#  [ -10.01    0.      0.  ]
#  [-100.      0.      0.  ]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' ' ' 'x']
#  ['o' 'x' ' ']
#
#  [   0.   -190.   -100.  ]
#  [   0.      0.   -100.  ]
#  [   0.   -100.    -10.01]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' 'x' 'o']
#  [' ' ' ' 'x']
#
#  [-10.01   0.     0.  ]
#  [  0.     0.     0.  ]
#  [  0.     0.     0.  ]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['x' 'o' ' ']
#  [' ' 'x' 'x']
#
#  [-190.      0.      0.  ]
#  [-100.      0.      0.  ]
#  [ -10.01    0.      0.  ]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' 'o' ' ']
#  ['x' ' ' 'x']
#
#  [ 0.e+00 -1.e+02  0.e+00]
#  [ 0.e+00  0.e+00  0.e+00]
#  [ 0.e+00 -1.e-02 -1.e+02]
#
# -------------------------
#
#  ['o' ' ' ' ']
#  ['x' ' ' 'x']
#  [' ' 'o' 'x']
#
#  [  0.     0.     0.  ]
#  [  0.     0.     0.  ]
#  [-10.01   0.     0.  ]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'o' ' ']
#  ['x' 'o' 'x']
#
#  [-1.0e-02  0.0e+00  0.0e+00]
#  [ 0.0e+00  0.0e+00  0.0e+00]
#  [-1.0e+02  0.0e+00 -1.9e+02]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' 'o' 'o']
#  ['x' ' ' ' ']
#
#  [ 319.83 -497.97 -604.42]
#  [-518.15 -487.45 -468.12]
#  [-493.46  561.94  218.78]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' 'x']
#  ['o' 'x' ' ']
#
#  [ 238.13 -616.04 -562.2 ]
#  [-526.27  234.82 -683.25]
#  [-526.3  -642.08   84.59]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' 'o' 'o']
#  [' ' 'x' 'x']
#
#  [-588.46   55.04 -334.53]
#  [ 266.95 -582.78 -487.94]
#  [ 265.36 -416.46 -489.51]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  ['x' ' ' 'x']
#  [' ' ' ' 'o']
#
#  [-572.53 -543.31 -573.64]
#  [-641.75  345.74 -488.27]
#  [ 144.16   89.8  -513.17]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['x' 'o' 'x']
#  [' ' 'o' 'o']
#
#  [ -95.92  -90.28 -677.94]
#  [-537.57 -742.06 -587.44]
#  [ -87.68 -534.81 -484.69]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' 'o' 'x']
#  ['x' 'o' ' ']
#
#  [ 372.46  220.72 -665.06]
#  [-493.11 -514.46 -539.29]
#  [-708.68 -576.17   63.01]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' ' ']
#  ['x' 'o' 'x']
#
#  [ 408.6  -593.37 -415.49]
#  [ 136.15 -522.83  171.96]
#  [-609.62 -555.12 -390.23]
#
# -------------------------
#
#  ['o' 'o' ' ']
#  [' ' 'x' 'x']
#  ['x' ' ' 'o']
#
#  [-579.54 -478.78  351.4 ]
#  [ 295.91 -673.6  -623.77]
#  [-627.86  248.66 -666.07]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [ -10.01    0.   -100.  ]
#  [   0.      0.      0.  ]
#  [   0.   -100.      0.  ]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['o' 'o' ' ']
#  [' ' 'x' 'x']
#
#  [   0.    0. -100.]
#  [-100. -271.   20.]
#  [   0.    0. -100.]
#
# -------------------------
#
#  ['x' 'o' 'x']
#  ['x' 'x' ' ']
#  ['o' ' ' 'o']
#
#  [-100.    0.    0.]
#  [-190.    0.    0.]
#  [   0.   20.    0.]
#
# -------------------------
#
#  ['o' 'x' 'o']
#  [' ' ' ' 'x']
#  ['x' 'x' 'o']
#
#  [ 0.  0.  0.]
#  [ 0. 20.  0.]
#  [ 0.  0.  0.]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' 'o']
#  [' ' 'x' 'x']
#
#  [ 0.    0.    0.  ]
#  [ 0.    0.    0.  ]
#  [-0.01  0.    0.  ]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  ['o' 'x' ' ']
#  [' ' 'o' 'x']
#
#  [-100.    0.    0.]
#  [   0. -100.    0.]
#  [  20. -100.    0.]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [0.   0.   0.  ]
#  [0.   1.59 0.  ]
#  [0.   0.   0.  ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' 'x']
#  [' ' 'x' ' ']
#
#  [-10.01   0.     0.  ]
#  [  0.     0.     0.  ]
#  [  0.     0.     0.  ]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['x' 'o' 'x']
#  ['x' 'o' 'o']
#
#  [   0.    39.6    0. ]
#  [ -98.4  -98.4    0. ]
#  [   0.  -100.  -100. ]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' 'x' 'o']
#  ['x' 'x' 'o']
#
#  [   0. -100.   20.]
#  [   0.    0. -100.]
#  [   0. -100. -100.]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['x' 'o' 'x']
#  ['x' 'o' ' ']
#
#  [   0.      0.   -100.  ]
#  [   0.      0.      0.  ]
#  [   0.      0.    -10.01]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' 'x']
#  ['x' 'x' 'o']
#
#  [  20.    0.    0.]
#  [   0. -100.    0.]
#  [   0.    0. -271.]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [   3.02    0.      0.  ]
#  [-100.      0.      0.  ]
#  [   0.   -100.   -100.  ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'x' ' ']
#  [' ' 'x' 'o']
#
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [-3.000e-02  0.000e+00 -1.001e+01]
#  [ 0.000e+00 -1.900e+02  0.000e+00]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [ -10.01    0.   -100.  ]
#  [   0.      0.      0.  ]
#  [-100.   -100.      0.  ]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['x' 'x' 'o']
#  ['o' ' ' 'x']
#
#  [   0.   -190.      0.  ]
#  [-190.      0.   -100.  ]
#  [   0.    -10.01    0.  ]
#
# -------------------------
#
#  ['o' 'x' 'x']
#  [' ' 'o' 'o']
#  ['x' ' ' 'x']
#
#  [ 0.  0.  0.]
#  [20.  0.  0.]
#  [ 0.  0.  0.]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' 'o']
#  [' ' 'x' 'x']
#
#  [ 164.75 -529.76 -339.12]
#  [ 142.48 -341.85 -614.77]
#  [ 279.49 -150.76 -659.21]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [ 136.68 -599.85 -630.15]
#  [ 127.98  215.87 -315.84]
#  [-418.29 -459.75 -594.3 ]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  ['o' ' ' ' ']
#  [' ' 'o' 'x']
#
#  [-544.95 -673.31 -664.57]
#  [-644.74  486.59  137.37]
#  [ 217.57 -614.83 -660.27]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  [' ' 'x' 'x']
#  ['o' 'x' ' ']
#
#  [ 459.6  -288.63 -356.79]
#  [ 271.56 -186.91 -429.02]
#  [-311.29 -243.79   72.3 ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' 'o' ' ']
#  ['x' 'x' ' ']
#
#  [  97.09 -626.68 -552.38]
#  [-699.39 -619.15  462.23]
#  [-648.55 -604.02  317.95]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'o' 'o']
#  ['x' 'o' 'x']
#
#  [ -70.62  -57.42 -475.78]
#  [ -55.68 -351.07 -349.08]
#  [-661.84 -274.09 -663.94]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' 'x']
#  [' ' 'x' 'o']
#
#  [  -1.75 -472.32 -465.21]
#  [-506.31  282.77 -574.46]
#  [ 288.28 -693.53 -731.36]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['o' 'o' 'x']
#  ['x' 'o' ' ']
#
#  [ 308.22 -526.1   513.1 ]
#  [-489.62 -504.81 -542.15]
#  [-609.8  -508.94  167.84]
#
# -------------------------
#
#  ['x' 'x' 'o']
#  [' ' 'o' ' ']
#  [' ' 'o' 'x']
#
#  [-684.31 -718.98 -706.84]
#  [ 234.39 -758.65  161.67]
#  [ 418.21 -660.16 -586.25]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  ['x' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [-815.85   -2.99 -772.63]
#  [-718.6   -49.45  -34.87]
#  [-718.86 -772.59 -652.24]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'x' ' ']
#  ['o' 'x' 'o']
#
#  [  -2.08 -486.01 -523.69]
#  [ 148.21 -550.7   222.47]
#  [-626.04 -604.78 -452.19]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  [' ' 'o' 'x']
#  ['x' 'o' ' ']
#
#  [ 241.59 -480.15 -240.78]
#  [  71.89 -414.8  -302.6 ]
#  [-571.97 -474.42   -1.54]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'o' 'x']
#  ['x' 'o' ' ']
#
#  [   0.   20.    0.]
#  [   0.    0.    0.]
#  [   0. -100.    0.]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [ 0.e+00 -1.e-02  0.e+00]
#  [ 0.e+00  0.e+00  0.e+00]
#  [ 0.e+00 -1.e+02  0.e+00]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  [' ' 'x' 'x']
#  ['o' 'o' ' ']
#
#  [-10.01   0.     0.  ]
#  [  3.16   0.     0.  ]
#  [  0.     0.    20.25]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' 'x']
#  ['o' 'x' 'o']
#
#  [20.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  0.]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'o' 'x']
#  ['x' ' ' ' ']
#
#  [   0.    0.    0.]
#  [   0. -100. -100.]
#  [-100.   20.    0.]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['x' ' ' 'o']
#  ['x' ' ' ' ']
#
#  [-1.00e-02  0.00e+00  0.00e+00]
#  [-2.71e+02  0.00e+00  0.00e+00]
#  [ 0.00e+00  0.00e+00 -1.00e-02]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' 'x' 'o']
#  ['o' ' ' 'x']
#
#  [ 318.77 -542.29  189.89]
#  [-393.87 -606.71 -603.91]
#  [-520.79   76.49 -658.32]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  ['x' ' ' 'o']
#  ['x' 'x' 'o']
#
#  [ 394.35 -526.29  582.18]
#  [-546.33  206.9  -644.63]
#  [-641.76 -416.75 -490.18]
#
# -------------------------
#
#  ['x' ' ' 'o']
#  ['o' 'o' 'x']
#  [' ' 'x' ' ']
#
#  [-661.33   38.31 -742.8 ]
#  [-703.59 -634.33 -525.52]
#  [ 228.8  -664.13  138.84]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['o' 'o' 'x']
#  [' ' 'x' ' ']
#
#  [-4.9000e-01 -5.7418e+02 -4.9319e+02]
#  [-6.0306e+02 -6.3345e+02 -4.3764e+02]
#  [ 2.2221e+02 -3.7919e+02  1.3278e+02]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' 'o' 'x']
#  ['o' 'x' 'o']
#
#  [ -31.61  -57.27  -50.51]
#  [-528.03 -412.41 -346.85]
#  [-529.09 -190.   -531.05]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' ' ' 'x']
#  ['o' 'x' 'x']
#
#  [  20.    0.    0.]
#  [   0.    0.    0.]
#  [-190.    0.    0.]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' 'x']
#  ['x' 'x' 'o']
#
#  [   0.      0.      0.  ]
#  [   0.     -0.11    0.  ]
#  [-100.      0.      0.  ]
#
# -------------------------
#
#  [' ' 'o' 'o']
#  ['x' 'o' ' ']
#  [' ' 'x' 'x']
#
#  [  71.53 -249.48 -318.44]
#  [-341.41 -586.26   56.91]
#  [ 261.43 -550.94 -658.44]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['x' 'o' 'o']
#  [' ' 'o' 'x']
#
#  [ 549.6  -546.88  287.24]
#  [-516.74 -478.03 -300.26]
#  [  -1.38 -426.05 -505.48]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['o' ' ' 'x']
#  ['o' 'o' 'x']
#
#  [ 510.58 -501.82  295.46]
#  [-609.09  221.17 -513.63]
#  [-537.4  -436.   -449.67]
#
# -------------------------
#
#  [' ' 'o' ' ']
#  [' ' 'o' 'x']
#  ['x' 'x' 'o']
#
#  [ 135.75 -387.76  -16.61]
#  [  59.18  -96.12 -331.8 ]
#  [-673.98 -320.91 -169.37]
#
# -------------------------
#
#  ['o' ' ' 'o']
#  [' ' 'x' 'x']
#  [' ' 'x' 'o']
#
#  [-623.43  399.97 -431.22]
#  [ 433.81 -608.14 -570.12]
#  [ 210.84 -505.47 -572.79]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['x' 'o' 'o']
#  [' ' 'o' 'x']
#
#  [ 128.11  351.43 -242.85]
#  [-451.79 -483.08 -546.36]
#  [  37.79 -488.83 -243.15]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['o' 'x' ' ']
#  ['x' 'o' 'x']
#
#  [  0.     0.     0.  ]
#  [  0.     0.   -18.12]
#  [  0.     0.     0.  ]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['x' 'x' 'o']
#  [' ' ' ' ' ']
#
#  [   1.59    0.   -100.  ]
#  [-100.      0.      0.  ]
#  [   0.      0.      0.  ]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  [' ' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [ 278.21 -500.62 -519.85]
#  [ 317.32 -429.99 -529.  ]
#  [ 115.21 -353.62 -532.79]
#
# -------------------------
#
#  ['o' 'o' 'x']
#  [' ' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [-386.79 -556.05 -424.35]
#  [ 196.41  168.03  319.88]
#  [-386.26 -552.95 -484.08]
#
# -------------------------
#
#  [' ' 'x' 'o']
#  ['x' 'o' ' ']
#  ['x' 'o' ' ']
#
#  [ 211.55 -526.55 -480.36]
#  [-607.75 -427.78   49.72]
#  [-612.99 -511.04  388.47]
#
# -------------------------
#
#  ['o' ' ' 'x']
#  [' ' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [-605.25  113.8  -583.62]
#  [ 261.42 -534.27 -647.86]
#  [ 305.3  -602.18 -533.63]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  ['x' 'o' 'o']
#  ['x' ' ' 'o']
#
#  [   0.   -271.      0.  ]
#  [   0.      0.   -100.  ]
#  [-100.    -10.01    0.  ]
#
# -------------------------
#
#  [' ' ' ' 'o']
#  ['x' 'x' 'o']
#  ['o' 'x' 'x']
#
#  [ -10.01    0.   -100.  ]
#  [   0.   -100.      0.  ]
#  [   0.      0.      0.  ]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  ['o' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [ 235.87  410.57 -463.66]
#  [-209.6  -387.18 -603.94]
#  [ 244.84 -356.2  -473.94]
#
# -------------------------
#
#  [' ' 'x' ' ']
#  ['o' 'o' 'x']
#  [' ' 'x' 'o']
#
#  [ 247.57 -502.63   84.08]
#  [-472.38 -492.86 -414.56]
#  [  53.46 -585.75 -567.91]
#
# -------------------------
#
#  [' ' ' ' 'x']
#  [' ' 'x' 'o']
#  [' ' 'o' 'x']
#
#  [   0.      0.      0.  ]
#  [   0.      0.   -100.  ]
#  [ -18.12    0.      0.  ]
#
# -------------------------
#
#  [' ' 'x' 'x']
#  [' ' 'o' 'x']
#  ['x' 'o' 'o']
#
#  [20.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  0.]
#
# -------------------------
#
#  [' ' 'o' 'x']
#  ['o' ' ' ' ']
#  ['x' 'o' 'x']
#
#  [ 207.81 -490.85 -601.86]
#  [-475.77  273.7   358.91]
#  [-506.86 -566.46 -608.65]
#
# -------------------------

# %%
player1.stats.display()

# %% [markdown]
# ## Singe Game

# %%
for j in trange(1):

    player1 = QPlayer('x', QTableLearner())
    player2 = Randy('o')
    players = [player1, player2]

    game = Game(players)

    for i in range(1):
        game.run()

    QUtils.save_dict_to_file(filepath, player1.q_learner.q_table)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
q_table = QUtils.get_dict_from_file(filepath)
QUtils.pretty_print_q_table(q_table)
# Out:
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']
#
#  [ 0.    0.    0.  ]
#  [-0.01  0.    0.  ]
#  [ 0.    0.    0.  ]
#
# -------------------------
#
#  [' ' ' ' ' ']
#  ['x' 'o' ' ']
#  [' ' ' ' ' ']
#
#  [-1.e-02  0.e+00  0.e+00]
#  [-1.e+02 -1.e+02  0.e+00]
#  [ 0.e+00  0.e+00  0.e+00]
#
# -------------------------
#
#  ['x' ' ' ' ']
#  ['x' 'o' ' ']
#  ['o' ' ' ' ']
#
#  [-100.    -10.01    0.  ]
#  [   0.      0.      0.  ]
#  [-100.      0.      0.  ]
#
# -------------------------

# %% [markdown]
# # Control Results

# %%
player1 = Randy('x')
player2 = Randy('o')
players = [player1, player2]

for j in trange(100):
    game = Game(players)
    for i in range(10000):
        game.run()

player1.stats.display()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Games     won    |    lost    |    draw    | total games
#         585293   |   288065   |   126642   |  1000000
#          59%     |    29%     |    13%     |    100%

# %% [markdown]
# # ToDo

# %% [markdown]
# * Test schreiben mit Mocks -> abdecken von (Hannes)
#     * richtiges Abspeichern
#     * richtige Ausgabe
#     * richtiges Lernen
# * Statistiken Überprüfer (Hannes)
# * Test mit 2 Randy player -> 100.000 Durchgänge (Hannes)
# * Training mit mehr Durchgängen -> großes qtable file erstellen (Kevin)
# * Docu anpassen (Hannes)
# * Klassendiagramme mit plantuml (da wo es funzt, Kevin)
# * QNN Learner erzeugen (Kevin)

# %% [markdown]
# - servertest
# - farbige resultate -> Heatmap
# - redundante zustände
# - zwischenstände für statistiken
# - Lernentwicklung im Bericht
