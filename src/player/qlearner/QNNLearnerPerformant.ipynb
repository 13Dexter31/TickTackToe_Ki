# %% [markdown]
# ### 1.4 QNN (Q-Wertbasiertes Neuronales Netzwerk)
#
# Für die Erweiterbarkeit unseres Codes ist uns aufgefallen, dass der Q-Algorithmus seine Grenzen bei Spielen mit einem beinahe unendlichen Zustandsraum aufweist. Spiele wie Schach oder Go haben einen derart riesigen Zustandsraum aller möglichen Züge, der ohne weitere Hilfe nicht einfach durch ausprobieren komplett erkundet werden kann. Um dem Prinzip des bestärkenden Lernens nahe zu kommen, müssen andere Methoden gefunden werden, um zukünftige Züge oder sogar Strategien bei unendlich wirkenden Zustandsräumen hervorzusagen. Hierfür soll ein neuronales Netzwerk mit mehreren Schichten zum Einsatz kommen.
#
# Der Gedanke dahinter ist, dass man nicht mehr versucht alle Zustände zu erkunden und perfekt vorherzusagen, sondern eine Struktur oder sogar Strategie in gewissen Zügen zu erkennen. Der Fokus des neuronalen Netzes soll damit sein, Strukturen in zeitlich aufeinanderfolgender Züge zu erkennen und bei unbekannten Zuständen einen Schätzwert auf Basis bisher bekannter Strategien ausgeben.
#
# Ein neuronales Netzwerk besteht zumeist aus Eingabevektoren, verschiedenste versteckte Schichten sowie Ausgabevektoren. Genauso wie die Q-Funktion, sollen dem QNN gewisse Parameter als Eingabevektoren mitgegeben werden. Dazu gehört der aktuelle Zustand des Bretts, die ausgewählte Aktion auf Basis vorheriger Werte aus dem QNN Modell und ggf. die Belohnung. Als Ausgabevektor soll, genauso wie bei der Q-Funktion, ein Q-Wert sein, der die maximale Belohnung des aktuellen Zustand-Aktion-Paares beschreibt.
#
# Die Lerndaten erstellt der QNN Agent selbst, durch das explorative Erkunden mittels dem Explorationsfaktor namens "Theta". Anhand der explorierten Daten und erlangten Belohnungen wird das QNN selbst die besten Züge herausfinden.

# %%
from abc import abstractmethod
from pathlib import Path
from build.player.QPlayer import QPlayer
from build.player.qlearner.QLearner import QLearner
from build.Board import Board

import numpy as np
import keras.models as Km
import keras.layers as kl

import os
import random

# %%
class QNNLearner(QLearner):
    """
    QLearner specification for neural network learning
    """

    def __init__(self, model = None, learn_rate=0.1, discount_factor=0.8, batch_size=10):
        """
        :param model: used qnn model structure
        :param learn_rate: learning rate of this q learner
        :param discount_factor: discount factor of this q learner
        """
        self.possible_actions = {0:[1, 1], 1:[2, 1], 2:[3, 1], 3:[1, 2], 4:[2, 2], 5:[3, 2], 6:[1, 3], 7:[2, 3], 8:[3, 3]}
        self.learn_rate = learn_rate
        self.model = model
        self.discount_factor = discount_factor
        self.memory = []
        self.count_memory = 0
        self.batch_size = batch_size

    def update(self, prev_state, state, prev_move, reward):
        """
        Update q players knowledge by learning offline or online
        :param prev_state: previous known state
        :param state: new state
        :param prev_move: previous made move
        :param reward: previous reward
        """
        self.model.train_model(prev_state,state,prev_move,reward,self.discount_factor)

    def select_move(self, state, theta=0.1):
        """
        Select the best move or, if exploring, a random move
        :param state: current state
        :param theta: temperature value (optional)
        :return: chosen action
        """
        p = random.uniform(0, 1)
        if p > theta and state is not None:
            action = np.argmax(self.model.predict_model(state))
            #action = self.possible_actions[idx]
        else:
            action = np.random.randint(0, len(self.possible_actions))

        return action # return choosen move

# %%
class Model:
    """
    Model class for all 2 player based games with neural network training
    """

    def __init__(self, tag, observation_space=9, action_space=9, discount_factor=0.8):
        """
        :param tag: used tag for neural network model (e.g. 1 for first player and -1 for second)
        """
        self.tag = tag
        self.epsilon = 0.1
        self.alpha = 0.5
        self.gamma = 1
        self.model = self.load_model()
        self.observation_space = observation_space
        self.action_space = action_space

    def load_model(self):
        """
        Loads previously saved model
        :return: loaded model
        """
        if self.tag == 1:
            tag = '_first'
        else:
            tag = '_second'

        s = 'model_values' + tag + '_performant.h5'
        model_file = Path(s)

        if model_file.is_file():
            print('load model')
            model = Km.load_model(s)
            print('load model: ' + s)
        else:
            model = self.create_model()
        return model

    def predict_model(self, state):
        state = self.one_hot_encode_state(state)
        target = self.model.predict(state)
        return target

    @abstractmethod
    def create_model(self):
        """
        Create new model with appropriate number of layers and network structure
        :return: created model
        """
        pass

    @abstractmethod
    def one_hot_encode_state(self, state):
        """
        Creates a tensor (2 dim array) based on a state and a move as input vector for nn
        :param state: current state
        :param move: current move
        :return: created tensor
        """
        pass

    def train_model(self, prev_state, new_state, prev_move, reward, discount_factor=0.8):
        """
        Train the model based on an input tensor
        :param prev_state: previous state
        :param prev_move: previous move
        :param target: calculated q value or reward (target vector)
        :param epochs: number of epochs
        """
        prev_state = self.one_hot_encode_state(prev_state)
        new_state = self.one_hot_encode_state(new_state)

        target = reward + discount_factor * np.max( self.model.predict(new_state))
        target_vector = self.model.predict(prev_state)[0]
        target_vector[prev_move] = target
        self.model.fit(prev_state, target_vector.reshape(-1, self.action_space), epochs=1, verbose=0)

       # loss = self.model.evaluate(prev_state, target_vector.reshape(-1, self.action_space), batch_size=256, verbose=0)[0]
        #print('planning number: loss', loss)

    def save_model(self):
        """
        save model as h5 file
        """
        if self.tag == 1:
            tag = '_first'
        else:
            tag = '_second'
        s = 'model_values' + tag + '.h5'

        try:
            os.remove(s)
        except:
            pass

        self.model.save(s)

# %%
class TicTacToeModel(Model):
    """
    Special model for tic tac toe games.

    Consists of 2x9 input vector, dense network of 9 layers and a 9 sized target vector.
    Input vector consists an array with length 9 for the chosen move and an array for the state.
    Target vector consists of 9 sized array for 9 possible rewards (one for each action).
    """

    def __init__(self, tag, observation_space=9, action_space=9, discount_factor=0.8):

        self.observation_space = observation_space
        self.action_space = action_space
        super().__init__(tag, self.observation_space, self.action_space, discount_factor)

        pass

    def create_model(self):
        """
        Creates keras model
        :return: keras model
        """
        print('new model')

        #model = km.load_model("qnn_model")

        model = Km.Sequential()
        model.add(kl.InputLayer(batch_input_shape=(1, self.observation_space)))
        model.add(kl.Dense(20, activation='relu'))
        model.add(kl.Dense(self.action_space, activation='linear'))
        model.compile(loss='mse', optimizer='adam', metrics=['mae'])

        # adam = ko.Adam(lr=0.001)

        # model.compile(optimizer='Adam', loss='mean_absolute_error', metrics=['accuracy'])
        #model.save("qnn_model")

        model.summary()

        return model

    def one_hot_encode_state(self, state):
        """
        One hot encoding for the state.
        Each field input of 3x3 matrix will be displayed with 0 (blank), 1 (player 1), -1 (player 2)
        :param state: state to encode
        :return: encoded state
        """
        state = state.flatten()
        for i in range(len(state)):
            if state[i] is None:
                state[i] = 0
            if state[i] == 'x':
                state[i] = 1
            if state[i] == 'o':
                state[i] = -1
        state = np.asarray(state).astype('int')
        state = state.reshape((1, 9))

        return state

# %%
from build.Game import Game
from tqdm.notebook import trange

# %%
for j in trange(100):

    model1 = TicTacToeModel(1)
    model2 = TicTacToeModel(-1)
    player1 = QPlayer('x', QNNLearner(model=model1))
    player2 = QPlayer('o', QNNLearner(model=model2))
    players = [player1, player2]

    game = Game(players)

    for i in range(10):
        game.run()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# new model
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_73 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_74 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_75 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_77 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_79 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_80 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_81 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_82 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_83 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_85 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_86 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_87 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_89 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_91 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_92 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_93 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_53"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_95 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_54"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_97 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_98 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_99 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_56"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_101 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_102 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_103 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_104 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_105 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_59"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_106 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_107 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_60"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_108 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_109 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_111 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_112 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_113 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_114 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_115 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_116 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_117 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_118 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_119 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_66"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_120 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_121 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_67"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_122 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_123 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_124 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_125 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_126 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_127 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_128 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_129 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_130 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_131 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_132 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_133 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_134 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_135 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_136 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_137 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_138 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_139 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_140 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_141 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_142 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_143 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_144 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_145 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_146 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_147 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_80"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_148 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_149 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_81"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_150 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_151 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_82"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_152 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_153 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_83"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_154 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_155 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_156 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_157 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_158 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_159 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_160 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_161 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_162 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_163 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_164 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_165 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_166 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_167 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_90"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_168 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_169 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_91"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_170 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_171 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_92"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_172 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_173 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_93"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_174 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_175 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_94"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_176 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_177 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_95"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_178 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_179 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_96"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_180 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_181 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_97"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_182 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_183 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_98"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_184 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_185 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_99"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_186 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_187 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_100"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_188 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_189 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_101"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_190 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_191 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_102"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_192 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_193 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_103"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_194 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_195 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_104"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_196 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_197 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_105"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_198 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_199 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_106"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_200 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_201 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_107"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_202 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_203 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_108"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_204 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_205 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_109"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_206 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_207 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_110"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_208 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_209 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_111"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_210 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_211 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_112"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_212 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_213 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_113"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_214 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_215 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_114"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_216 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_217 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_115"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_218 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_219 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_116"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_220 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_221 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_117"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_222 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_223 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_118"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_224 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_225 (Dense)            (1, 9)                    189
# ...
# _________________________________________________________________
# dense_261 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_137"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_262 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_263 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_138"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_264 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_265 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_139"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_266 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_267 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_140"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_268 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_269 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_141"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_270 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_271 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_142"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_272 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_273 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_143"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_274 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_275 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_144"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_276 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_277 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_145"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_278 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_279 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_146"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_280 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_281 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_147"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_282 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_283 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_154"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_296 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_297 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_155"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_298 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_299 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_156"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_300 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_301 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_157"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_302 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_303 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_158"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_304 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_305 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_159"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_306 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_307 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_160"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_308 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_309 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_161"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_310 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_311 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_162"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_312 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_313 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_163"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_314 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_315 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_164"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_316 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_317 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_165"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_318 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_319 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_166"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_320 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_321 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# new model
# Model: "sequential_167"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_322 (Dense)            (1, 20)                   200
# _________________________________________________________________
# dense_323 (Dense)            (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = TicTacToeModel(1)
state = np.array([[None,"x","x"],[None,"o","o"],[None,None,None]])
model.predict_model(state)
# Out:
# new model
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_62 (Dense)             (1, 20)                   200
# _________________________________________________________________
# dense_63 (Dense)             (1, 9)                    189
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________
# array([[-0.75077385,  0.39786673, -0.15094791,  0.4045996 , -0.13271517,
#          0.5515286 ,  0.11903673, -0.11275794,  0.23266867]],
#       dtype=float32)
